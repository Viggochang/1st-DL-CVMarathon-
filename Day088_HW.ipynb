# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                   activation='relu',
                                   name='hidden_layer'+str(i))(x)
            x = BatchNormalization()(x)
        
        out = keras.layers.Dense(units=output_units, 
                                 activation='softmax',
                                 name='output')(x)
        
        model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    
    def __init__(self, val_data=(x_test, y_test)):
        self.validation_data = val_data
    
    def on_train_begin(self, epoch, logs={}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
            except:
                self.params['metrics'] = i

    def on_epoch_end(self, epoch, logs={}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        tp = keras.metrics.TruePositives()
        tp.reset_states()
        tp.update_state(y_true, y_pred)
        logs['val_tp'] = tp.result()
        
        tn = keras.metrics.TrueNegatives()
        tn.reset_states()
        tn.update_state(y_true, y_pred)
        logs['val_tn'] = tn.result()
    
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          validation_data=(x_test, y_test),
          shuffle=True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Epoch 1/25
# 49/49 [==============================] - 3s 61ms/step - loss: 2.2401 - accuracy: 0.2606 - val_loss: 2.1753 - val_accuracy: 0.1949 - val_tp: 1.0000 - val_tn: 1000.0000
# Epoch 2/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.7708 - accuracy: 0.3835 - val_loss: 2.0204 - val_accuracy: 0.2803 - val_tp: 19.0000 - val_tn: 1000.0000
# Epoch 3/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.6380 - accuracy: 0.4266 - val_loss: 1.8585 - val_accuracy: 0.3545 - val_tp: 27.0000 - val_tn: 1000.0000
# Epoch 4/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.5604 - accuracy: 0.4540 - val_loss: 1.7460 - val_accuracy: 0.3923 - val_tp: 58.0000 - val_tn: 1000.0000
# Epoch 5/25
# 49/49 [==============================] - 3s 58ms/step - loss: 1.5063 - accuracy: 0.4731 - val_loss: 1.6600 - val_accuracy: 0.4195 - val_tp: 184.0000 - val_tn: 997.0000
# Epoch 6/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.4614 - accuracy: 0.4885 - val_loss: 1.6117 - val_accuracy: 0.4307 - val_tp: 235.0000 - val_tn: 998.0000
# Epoch 7/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.4245 - accuracy: 0.5010 - val_loss: 1.5704 - val_accuracy: 0.4424 - val_tp: 408.0000 - val_tn: 989.0000
# Epoch 8/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.3906 - accuracy: 0.5144 - val_loss: 1.5235 - val_accuracy: 0.4631 - val_tp: 426.0000 - val_tn: 989.0000
# Epoch 9/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.3613 - accuracy: 0.5254 - val_loss: 1.5062 - val_accuracy: 0.4656 - val_tp: 491.0000 - val_tn: 984.0000
# Epoch 10/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.3346 - accuracy: 0.5339 - val_loss: 1.5059 - val_accuracy: 0.4712 - val_tp: 536.0000 - val_tn: 985.0000
# Epoch 11/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.3099 - accuracy: 0.5426 - val_loss: 1.4863 - val_accuracy: 0.4772 - val_tp: 660.0000 - val_tn: 975.0000
# Epoch 12/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.2875 - accuracy: 0.5510 - val_loss: 1.4811 - val_accuracy: 0.4768 - val_tp: 597.0000 - val_tn: 980.0000
# Epoch 13/25
# 49/49 [==============================] - 3s 58ms/step - loss: 1.2646 - accuracy: 0.5606 - val_loss: 1.4687 - val_accuracy: 0.4809 - val_tp: 612.0000 - val_tn: 977.0000
# Epoch 14/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.2419 - accuracy: 0.5683 - val_loss: 1.4668 - val_accuracy: 0.4831 - val_tp: 579.0000 - val_tn: 979.0000
# Epoch 15/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.2202 - accuracy: 0.5750 - val_loss: 1.4620 - val_accuracy: 0.4856 - val_tp: 629.0000 - val_tn: 978.0000
# Epoch 16/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.2012 - accuracy: 0.5837 - val_loss: 1.4531 - val_accuracy: 0.4889 - val_tp: 655.0000 - val_tn: 977.0000
# Epoch 17/25
# 49/49 [==============================] - 3s 62ms/step - loss: 1.1805 - accuracy: 0.5910 - val_loss: 1.4617 - val_accuracy: 0.4878 - val_tp: 815.0000 - val_tn: 971.0000
# Epoch 18/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.1614 - accuracy: 0.5984 - val_loss: 1.4487 - val_accuracy: 0.4920 - val_tp: 685.0000 - val_tn: 974.0000
# Epoch 19/25
# 49/49 [==============================] - 3s 62ms/step - loss: 1.1437 - accuracy: 0.6058 - val_loss: 1.4595 - val_accuracy: 0.4846 - val_tp: 746.0000 - val_tn: 972.0000
# Epoch 20/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.1245 - accuracy: 0.6112 - val_loss: 1.4628 - val_accuracy: 0.4870 - val_tp: 661.0000 - val_tn: 976.0000
# Epoch 21/25
# 49/49 [==============================] - 3s 55ms/step - loss: 1.1065 - accuracy: 0.6193 - val_loss: 1.4464 - val_accuracy: 0.4949 - val_tp: 656.0000 - val_tn: 977.0000
# Epoch 22/25
# 49/49 [==============================] - 3s 56ms/step - loss: 1.0907 - accuracy: 0.6254 - val_loss: 1.4582 - val_accuracy: 0.4931 - val_tp: 667.0000 - val_tn: 978.0000
# Epoch 23/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.0725 - accuracy: 0.6326 - val_loss: 1.4516 - val_accuracy: 0.4955 - val_tp: 609.0000 - val_tn: 982.0000
# Epoch 24/25
# 49/49 [==============================] - 3s 54ms/step - loss: 1.0542 - accuracy: 0.6386 - val_loss: 1.4571 - val_accuracy: 0.4951 - val_tp: 658.0000 - val_tn: 982.0000
# Epoch 25/25
# 49/49 [==============================] - 3s 57ms/step - loss: 1.0383 - accuracy: 0.6455 - val_loss: 1.4605 - val_accuracy: 0.4930 - val_tp: 721.0000 - val_tn: 977.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
