# %% [markdown]
# ## 讀檔案

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 忽略警告訊息
import warnings
warnings.filterwarnings('ignore')

data_train = pd.read_csv('/Users/shao/learning_python/ML marathon/train_data.csv')
#data_train = data_train.drop(['name','email_address','director_fees','loan_advances','restricted_stock_deferred'], axis=1)

data_train
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-796adf3248a8> in <module>
#       7 warnings.filterwarnings('ignore')
#       8
# ----> 9 data_train = pd.read_csv('/Users/shao/learning_python/ML marathon/train_data.csv')
#      10 #data_train = data_train.drop(['name','email_address','director_fees','loan_advances','restricted_stock_deferred'], axis=1)
#      11
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/shao/learning_python/ML marathon/train_data.csv does not exist: '/Users/shao/learning_python/ML marathon/train_data.csv'

# %%
# 刪除不必要欄位 (eg.name)
# 判斷 outlier
# 清理資料: 補缺漏值、錯誤值、離群值
# 標準化、最大最小化
# 選擇特徵參數(剃除不相關的)  Day30

# OneHotCoding 或 LabelCoding 
# 選擇模型
# 資料切分 訓練集、驗證集
# 選擇參數

# %% [markdown]
# ## 各欄位進行統計敘述

# %%
pd.set_option('display.float_format',lambda x : '%.f' % x)
print(data_train.shape)
data_train.describe()
# Out:
# (113, 22)
#         bonus  deferral_payments  deferred_income  director_fees  \
# count      61                 28               34             13
# mean  1147436             634437          -462566          89398
# std   1505189             860365           809539          41143
# min     70000            -102500         -3504386           3285
# 25%    450000              76568          -552703         101250
# 50%    750000             195190          -117534         108579
# 75%   1000000             834205           -27083         112492
# max   8000000            2964506            -1042         125034
#
#        exercised_stock_options  expenses  from_messages  \
# count                       81        73             65
# mean                   2985081     51041            711
# std                    6004174     47597           2074
# min                       3285       148             12
# 25%                     400478     18834             19
# 50%                     850010     41953             45
# 75%                    2165172     59175            215
# max                   34348384    228763          14368
#
#        from_poi_to_this_person  from_this_person_to_poi  loan_advances  \
# count                       65                       65              2
# mean                        65                       40       40962500
# std                         92                       89       57364038
# min                          0                        0         400000
# 25%                         10                        0       20681250
# 50%                         28                        7       40962500
# 75%                         88                       27       61243750
# max                        528                      411       81525000
#
#        long_term_incentive    other  restricted_stock  \
# count                   49       69                82
# mean                792617   447177           1294855
# std                 950464  1341564           2498335
# min                  71023        2             44093
# 25%                 275000      972            268922
# 50%                 422158    52382            462822
# 75%                 831809   362096            966490
# max                5145434 10359729          14761694
#
#        restricted_stock_deferred  salary  shared_receipt_with_poi  \
# count                         10      73                       65
# mean                     -221886  273903                     1111
# std                       205191  171665                     1166
# min                      -560222     477                        2
# 25%                      -389622  206121                      178
# 50%                      -139856  251654                      599
# 75%                       -77953  288589                     1902
# max                        44093 1111258                     4527
#
#        to_messages  total_payments  total_stock_value
# count           65              96                 98
# mean          2156         2590977            3527136
# std           2812        10566446            7182997
# min             57             148             -44093
# 25%            517          302402             421152
# 50%           1088         1106740             997971
# 75%           2649         1985668            2493616
# max          15149       103559793           49110078

# %% [markdown]
# ## 統計缺值數量

# %%
nan = data_train.isnull().sum(axis=0).reset_index()
nan.columns = ['col', 'nan_count']
nan.index = np.arange(1, len(nan)+1)
nan
# Out:
#                           col  nan_count
# 1                        name          0
# 2                       bonus         52
# 3           deferral_payments         85
# 4             deferred_income         79
# 5               director_fees        100
# 6               email_address         30
# 7     exercised_stock_options         32
# 8                    expenses         40
# 9               from_messages         48
# 10    from_poi_to_this_person         48
# 11    from_this_person_to_poi         48
# 12              loan_advances        111
# 13        long_term_incentive         64
# 14                      other         44
# 15                        poi          0
# 16           restricted_stock         31
# 17  restricted_stock_deferred        103
# 18                     salary         40
# 19    shared_receipt_with_poi         48
# 20                to_messages         48
# 21             total_payments         17
# 22          total_stock_value         15

# %% [markdown]
# ## 刪除缺值過多的欄位

# %%
data_train = pd.read_csv('D:\\learning_ai\\期中考\\train_data.csv')
poi = data_train['poi']
data_train = data_train.drop(['poi','name', 'email_address', 'director_fees', 'loan_advances', 'restricted_stock_deferred'], axis=1)

print(data_train.shape)
#data_train.describe()
# Out:
# (113, 16)

# %%
from sklearn import preprocessing
# total_payments:bonus, salary, long_term_incentive, deferred_income, deferral_payments,
#               other, expenses 中位數
# total_stock_value:exercised_stock_options, restricted_stock  中位數
# from_messages, from_poi_to_this_person, from_this_person_to_poi, to_messages, shared_receipt_with_poi  補0
# poi

# %% [markdown]
# ## 補缺值、取log、最大最小化

# %%
pd.set_option('display.float_format',lambda x : '%.3f' % x)

dtrain = data_train.copy()
fin = ['bonus', 'salary', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'other', 'expenses', 'exercised_stock_options', 'restricted_stock']
mail = ['from_messages', 'from_poi_to_this_person', 'from_this_person_to_poi', 'to_messages', 'shared_receipt_with_poi']

for col in fin:
    fill = dtrain[col].median()
    dtrain[col].fillna(fill, inplace=True)
    if col == 'deferral_payments':
        dtrain.loc[dtrain[col]<0, col] = fill
        
for col in mail:
    dtrain[col].fillna(0, inplace=True)
    
    
dtrain['total_payments'] = 0
for col in fin:
    dtrain['total_payments'] += dtrain[col]
    
dtrain['total_stock_value'] = 0
for col in mail:
    dtrain['total_stock_value'] += dtrain[col]
    
fin.append('total_payments')
mail.append('total_stock_value')
    
for col in fin:
    if col != 'salary':
        if col == 'deferred_income':
            dtrain[col] *= (-1)
        dtrain[col] = np.log(dtrain[col])
    
for col in mail:
    scaler = preprocessing.StandardScaler()
    dtrain[col] = scaler.fit_transform(pd.DataFrame(dtrain[col]))
    
# for col in fin+mail:
#     scaler = preprocessing.MinMaxScaler()
#     dtrain[col] = scaler.fit_transform(pd.DataFrame(dtrain[col]))
    
scaler = preprocessing.MinMaxScaler()    
dtrain = scaler.fit_transform(dtrain)
dtrain = pd.DataFrame(dtrain)
dtrain.columns = data_train.columns
dtrain
# Out:
#      bonus  deferral_payments  deferred_income  exercised_stock_options  \
# 0    0.679              0.540            1.000                    0.940
# 1    0.925              0.540            0.582                    0.937
# 2    0.222              0.540            0.171                    0.670
# 3    0.514              0.540            0.582                    0.600
# 4    0.608              0.540            0.681                    0.600
# ..     ...                ...              ...                      ...
# 108  0.415              0.540            0.582                    0.600
# 109  0.500              0.540            0.582                    0.600
# 110  0.307              0.540            0.582                    0.235
# 111  0.500              0.540            0.582                    0.600
# 112  0.470              0.540            0.582                    0.564
#
#      expenses  from_messages  from_poi_to_this_person  \
# 0       0.784          0.001                    0.080
# 1       0.720          0.008                    0.167
# 2       0.686          0.003                    0.025
# 3       0.910          0.000                    0.000
# 4       0.747          0.010                    0.377
# ..        ...            ...                      ...
# 108     0.642          0.000                    0.000
# 109     0.791          0.003                    0.025
# 110     0.731          0.005                    0.013
# 111     0.159          0.001                    0.008
# 112     0.931          0.085                    0.140
#
#      from_this_person_to_poi  long_term_incentive  other  restricted_stock  \
# 0                      0.010                0.730  0.736             0.711
# 1                      0.073                0.770  0.602             0.868
# 2                      0.034                0.416  0.878             0.513
# 3                      0.000                0.499  0.843             0.534
# 4                      0.061                0.389  0.355             0.181
# ..                       ...                  ...    ...               ...
# 108                    0.000                0.416  0.782             0.422
# 109                    0.002                0.416  0.658             0.404
# 110                    0.000                0.416  0.658             0.404
# 111                    0.017                0.416  0.658             0.674
# 112                    0.158                0.416  0.379             0.370
#
#      salary  shared_receipt_with_poi  to_messages  total_payments  \
# 0     0.378                    0.191        0.060           0.713
# 1     1.000                    0.451        0.239           0.817
# 2     0.190                    0.020        0.015           0.324
# 3     0.202                    0.000        0.000           0.295
# 4     0.216                    0.483        0.171           0.171
# ..      ...                      ...          ...             ...
# 108   0.215                    0.000        0.000           0.185
# 109   0.226                    0.168        0.098           0.180
# 110   0.589                    0.161        0.059           0.087
# 111   0.226                    0.104        0.038           0.298
# 112   0.242                    1.000        1.000           0.145
#
#      total_stock_value
# 0                0.077
# 1                0.249
# 2                0.016
# 3                0.000
# 4                0.218
# ..                 ...
# 108              0.000
# 109              0.097
# 110              0.072
# 111              0.045
# 112              0.888
#
# [113 rows x 16 columns]

# %%
# 統計每個值的數量
col = 'to_messages'

print(f"nan_count:{nan.loc[nan['col']==col, 'nan_count'].values[0]}")

count = data_train[col].value_counts()
# 以 值 進行排序
count.sort_index(inplace=True)
count = count.reset_index()
count.columns = [col, 'count']
count
#count.loc[count['deferral_payments']==7961, 'count']
# Out:
# nan_count:48
#     to_messages  count
# 0            57      1
# 1           102      1
# 2           111      1
# 3           128      1
# 4           136      1
# 5           176      1
# 6           209      1
# 7           225      1
# 8           232      1
# 9           258      1
# 10          266      1
# 11          383      1
# 12          400      1
# 13          460      1
# 14          496      1
# 15          504      1
# 16          517      1
# 17          533      1
# 18          566      1
# 19          573      1
# 20          653      1
# 21          671      1
# 22          672      1
# 23          714      1
# 24          719      1
# 25          764      1
# 26          873      1
# 27          894      1
# 28          898      1
# 29          904      1
# 30          905      1
# 31          936      1
# 32         1088      1
# 33         1184      1
# 34         1238      1
# 35         1328      1
# 36         1433      1
# 37         1486      1
# 38         1522      1
# 39         1671      1
# 40         1744      1
# 41         1758      1
# 42         2192      1
# 43         2374      1
# 44         2475      1
# 45         2572      1
# 46         2598      1
# 47         2647      1
# 48         2649      1
# 49         2822      1
# 50         2902      1
# 51         3136      1
# 52         3221      1
# 53         3329      1
# 54         3523      1
# 55         3627      1
# 56         4009      1
# 57         4273      1
# 58         4607      1
# 59         6019      1
# 60         7259      1
# 61         7315      1
# 62         8305      1
# 63        12754      1
# 64        15149      1

# %%
#盒狀圖

dtrain.boxplot('total_stock_value')

# %%
# 直條圖

scaler = preprocessing.StandardScaler()
a = scaler.fit_transform(pd.DataFrame(dtrain['total_stock_value']))
scaler = preprocessing.MinMaxScaler()
a = scaler.fit_transform(pd.DataFrame(a))

pd.DataFrame(a).hist(bins=80)

plt.show()
